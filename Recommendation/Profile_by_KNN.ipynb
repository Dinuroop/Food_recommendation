# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn.neighbors import NearestNeighbors

df = pd.read_csv("C:\\Users\\SUVARNA\\Downloads\\data2.csv")

# %%
class Recommender:
    
    def __init__(self):
        self.df = pd.read_csv('C:\\Users\\SUVARNA\\Food Recommendation\\Data Processing\\dataset.csv')
    
    def get_features(self):
        #getting dummies of dataset
        nutrient_dummies = self.df.Nutrient.str.get_dummies()
        disease_dummies = self.df.Disease.str.get_dummies(sep=' ')
        diet_dummies = self.df.Diet.str.get_dummies(sep=' ')
        feature_df = pd.concat([nutrient_dummies,disease_dummies,diet_dummies],axis=1)
    
     
        return feature_df
    
    def k_neighbor(self,inputs):
        
        feature_df = self.get_features()
        
        #initializing model with k=20 neighbors
        model = NearestNeighbors(n_neighbors=40,algorithm='ball_tree')
        
        # fitting model with dataset features
        model.fit(feature_df)
        
        df_results = pd.DataFrame(columns=list(self.df.columns))
        
      
        # getting distance and indices for k nearest neighbor
        distnaces , indices = model.kneighbors(inputs)

        for i in list(indices):
            df_results = df_results.append(self.df.loc[i])
                
        df_results = df_results.filter(['Name','Nutrient','Veg_Non','Price','Review','Diet','Disease','description'])
        df_results = df_results.drop_duplicates(subset=['Name'])
        df_results = df_results.reset_index(drop=True)
        return df_results

# %%
ob = Recommender()
data = ob.get_features()

total_features = data.columns
d = dict()
for i in total_features:
    d[i]= 0
print(d)
# Out:
# {'calcium': 0, 'carbohydrates': 0, 'chloride': 0, 'fiber': 0, 'iodine': 0, 'iron': 0, 'magnesium': 0, 'manganese': 0, 'phosphorus': 0, 'potassium': 0, 'protien': 0, 'selenium': 0, 'vitamin_a': 0, 'vitamin_c': 0, 'vitamin_d': 0, 'vitamin_e': 0, 'anemia': 0, 'cancer': 0, 'diabeties': 0, 'eye_disease': 0, 'goitre': 0, 'heart_disease': 0, 'hypertension': 0, 'kidney_disease': 0, 'obesity': 0, 'pregnancy': 0, 'rickets': 0, 'scurvy': 0, 'alkaline_diet': 0, 'dash_diet': 0, 'high_fiber_diet': 0, 'high_protien_diet': 0, 'ketogenic_diet': 0, 'low_fat_diet': 0, 'vegan_diet': 0}

# %%
sample_input = ['high_protien_diet','gluten_free_diet','diabeties','anemia','calcium','protien']

for i in sample_input:
    
    d[i] = 1

final_input = list(d.values())
print(d)
# Out:
# {'calcium': 1, 'carbohydrates': 0, 'chloride': 0, 'fiber': 0, 'iodine': 0, 'iron': 0, 'magnesium': 0, 'manganese': 0, 'phosphorus': 0, 'potassium': 0, 'protien': 1, 'selenium': 0, 'vitamin_a': 0, 'vitamin_c': 0, 'vitamin_d': 0, 'vitamin_e': 0, 'anemia': 1, 'cancer': 0, 'diabeties': 1, 'eye_disease': 0, 'goitre': 0, 'heart_disease': 0, 'hypertension': 0, 'kidney_disease': 0, 'obesity': 0, 'pregnancy': 0, 'rickets': 0, 'scurvy': 0, 'alkaline_diet': 0, 'dash_diet': 0, 'high_fiber_diet': 0, 'high_protien_diet': 1, 'ketogenic_diet': 0, 'low_fat_diet': 0, 'vegan_diet': 0, 'gluten_free_diet': 1}

# %%
results = ob.k_neighbor([final_input]) # pass 2d array []
results
# Out:
# C:\Users\SUVARNA\AppData\Local\Programs\Python\Python3.9\lib\site-packages\sklearn\base.py:441: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
#                                             Name    Nutrient  Veg_Non Price  \
# 0                                     corn pulao     protien      veg   240
# 1                                    apple rabdi     calcium      veg   555
# 2                          apple and walnut cake   potassium      veg   660
# 3   lemon honey glazed sous vide corn on the cob     protien  non-veg   415
# 4                          walnut brownie gujiya   magnesium      veg   340
# 5              grilled almond barfi (sugar free)     calcium      veg   315
# 6                            apple and pear cake   potassium      veg   375
# 7                                tricolour pasta     calcium      veg   610
# 8                           mango and mint kheer     calcium      veg   300
# 9                            aata walnut cookies   manganese      veg   560
# 10                  holi special ice tea thandai     calcium      veg   560
# 11                                     plum cake   potassium      veg   420
# 12                 coffee marinated mutton chops    chloride  non-veg   475
# 13                               tricolour salad       fiber      veg   390
# 14                              gajar halwa tart   vitamin_d      veg   325
# 15       shepherds salad (tamatar-kheera salaad)       fiber      veg   310
# 16                              baked namak para   magnesium      veg   595
# 17                      holi special malai kofta  phosphorus      veg   660
# 18                                 almond pearls     protien      veg   330
# 19                       eggless coffee cupcakes   vitamin_d      veg   400
# 20                          eggless vanilla cake   potassium      veg   620
# 21                    gluten-free christmas cake   potassium      veg   575
# 22                   raspberry and balsamic dome   vitamin_a      veg   365
# 23                                  oats khichdi     protien      veg   650
#
#                                                  Diet  \
# 0                      high_protien_diet low_fat_diet
# 1    ketogenic_diet high_protien_diet low_fat_diet...
# 2                                        low_fat_diet
# 3      high_fiber_diet high_protien_diet low_fat_diet
# 4                                   high_protien_diet
# 5    high_protien_diet low_fat_diet high_fiber_die...
# 6                        high_fiber_diet low_fat_diet
# 7    ketogenic_diet high_protien_diet low_fat_diet...
# 8    ketogenic_diet high_protien_diet low_fat_diet...
# 9                        high_fiber_diet low_fat_diet
# 10   ketogenic_diet high_protien_diet low_fat_diet...
# 11                                       low_fat_diet
# 12                   high_protien_diet ketogenic_diet
# 13   ketogenic_diet high_fiber_diet high_protien_d...
# 14                                       low_fat_diet
# 15   ketogenic_diet high_fiber_diet high_protien_d...
# 16      ketogenic_diet high_protien_diet low_fat_diet
# 17                            low_fat_diet vegan_diet
# 18                                    high_fiber_diet
# 19                   high_protien_diet ketogenic_diet
# 20                                       low_fat_diet
# 21                     high_protien_diet low_fat_diet
# 22                                    high_fiber_diet
# 23                  high_fiber_diet high_protien_diet
#
#                                     Disease  \
# 0                                 diabeties
# 1                                 diabeties
# 2                                 diabeties
# 3             hypertension scurvy diabeties
# 4                                 diabeties
# 5                          goitre diabeties
# 6                                 diabeties
# 7                                    goitre
# 8                                 pregnancy
# 9                                 diabeties
# 10   heart_disease kidney_disease diabeties
# 11                                   scurvy
# 12                            anemia goitre
# 13                         goitre diabeties
# 14                           kidney_disease
# 15                         goitre diabeties
# 16                 obesity goitre diabeties
# 17                 kidney_disease diabeties
# 18                                   goitre
# 19                            anemia goitre
# 20                                   goitre
# 21                    goitre kidney_disease
# 22                                diabeties
# 23                  heart_disease pregnancy
#
#                                           description
# 0   बासमती चावल, अमेरिकन कॉर्न के दाने, जैतून का त...
# 1   apples, milk, sugar, green cardamoms, almonds ...
# 2   सेब, अंडे, अखरोट, चीनी, अखरोट, तेल, मैदा, बेकि...
# 3   young corn on the cob, honey, lemon juice, gar...
# 4   walnut brownie, chocolate sauce, chocolate chu...
# 5      khoya, sweetener (optional), almonds (crushed)
# 6   कोर, छिला और स्लाइस्ड एप्पल, कोर, छिला और स्ला...
# 7   penne, fresh broccoli, carrot, green onions, b...
# 8   milk, basmati rice, powdered sugar / sugar sub...
# 9   butter, castor sugar, aata, baking powder, cof...
# 10  ground white pepper (kali mirch), assam tea ba...
# 11  oven temp: 150 c-300 f, butter, sugar, eggs, a...
# 12  mutton chops, espresso, honey, balsamic vinega...
# 13  vinegar, honey/sugar, soy sauce, salt, garlic ...
# 14  white butter, breakfast sugar, milk full fat, ...
# 15  1 खीरा छीलकर कटा हुआ, प्याज, टमाटर, हरी मिर्च,...
# 16  whole wheat flour (atta), refined flour (maida...
# 17  potatoes, paneer (cottage cheese), maida, cori...
# 18  toasted almonds, blueberries, oats, corn flake...
# 19  maida/ flour, baking powder, sugar, cocoa powd...
# 20  maida, baking powder, castor sugar, butter, mi...
# 21  क्रिसमस ड्राई फ्रूट्स (पहले से भीगे हुए),  संत...
# 22  dark chocolate, butter, sugar, water, egg, egg...
# 23  क्विक कुकिंग ओट्स, मूंगदाल, जीरा, हल्दी पाउडर,...
