# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn.neighbors import NearestNeighbors

df = pd.read_csv("C:\\Users\\SUVARNA\\Downloads\\data2.csv")

# %%
class Recommender:
    
    def __init__(self):
        self.df = pd.read_csv('C:\\Users\\SUVARNA\\Food Recommendation\\Data Processing\\dataset.csv')
    
    def get_features(self):
        #getting dummies of dataset
        nutrient_dummies = self.df.Nutrient.str.get_dummies()
        disease_dummies = self.df.Disease.str.get_dummies(sep=' ')
        diet_dummies = self.df.Diet.str.get_dummies(sep=' ')
        feature_df = pd.concat([nutrient_dummies,disease_dummies,diet_dummies],axis=1)
    
     
        return feature_df
    
    def k_neighbor(self,inputs):
        
        feature_df = self.get_features()
        
        #initializing model with k=20 neighbors
        model = NearestNeighbors(n_neighbors=40,algorithm='ball_tree')
        
        # fitting model with dataset features
        model.fit(feature_df)
        
        df_results = pd.DataFrame(columns=list(self.df.columns))
        
      
        # getting distance and indices for k nearest neighbor
        distnaces , indices = model.kneighbors(inputs)

        for i in list(indices):
            df_results = df_results.append(self.df.loc[i])
                
        df_results = df_results.filter(['Name','Nutrient','Veg_Non','Price','Review','Diet','Disease','description'])
        df_results = df_results.drop_duplicates(subset=['Name'])
        df_results = df_results.reset_index(drop=True)
        return df_results

# %%
ob = Recommender()
data = ob.get_features()

total_features = data.columns
d = dict()
for i in total_features:
    d[i]= 0
print(d)
# Out:
# {'calcium': 0, 'carbohydrates': 0, 'chloride': 0, 'fiber': 0, 'iodine': 0, 'iron': 0, 'magnesium': 0, 'manganese': 0, 'phosphorus': 0, 'potassium': 0, 'protien': 0, 'selenium': 0, 'vitamin_a': 0, 'vitamin_c': 0, 'vitamin_d': 0, 'vitamin_e': 0, 'anemia': 0, 'cancer': 0, 'diabeties': 0, 'eye_disease': 0, 'goitre': 0, 'heart_disease': 0, 'hypertension': 0, 'kidney_disease': 0, 'obesity': 0, 'pregnancy': 0, 'rickets': 0, 'scurvy': 0, 'alkaline_diet': 0, 'dash_diet': 0, 'high_fiber_diet': 0, 'high_protien_diet': 0, 'ketogenic_diet': 0, 'low_fat_diet': 0, 'vegan_diet': 0}

# %%
sample_input = ['high_protien_diet','gluten_free_diet','diabeties','anemia','calcium','protien']

for i in sample_input:
    
    d[i] = 1

final_input = list(d.values())
print(d)
# Out:
# {'calcium': 1, 'carbohydrates': 0, 'chloride': 0, 'fiber': 0, 'iodine': 0, 'iron': 0, 'magnesium': 0, 'manganese': 0, 'phosphorus': 0, 'potassium': 0, 'protien': 1, 'selenium': 0, 'vitamin_a': 0, 'vitamin_c': 0, 'vitamin_d': 0, 'vitamin_e': 0, 'anemia': 1, 'cancer': 0, 'diabeties': 1, 'eye_disease': 0, 'goitre': 0, 'heart_disease': 0, 'hypertension': 0, 'kidney_disease': 0, 'obesity': 0, 'pregnancy': 0, 'rickets': 0, 'scurvy': 0, 'alkaline_diet': 0, 'dash_diet': 0, 'high_fiber_diet': 0, 'high_protien_diet': 1, 'ketogenic_diet': 0, 'low_fat_diet': 0, 'vegan_diet': 0, 'gluten_free_diet': 1}

# %%
results = ob.k_neighbor([final_input[:35]]) # pass 2d array []
results
# Out:
# c:\Users\SUVARNA\AppData\Local\Programs\Python\Python3.9\lib\site-packages\sklearn\base.py:441: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
#                                             Name       Nutrient  Veg_Non  \
# 0                                     corn pulao        protien      veg
# 1                          walnut brownie gujiya      magnesium      veg
# 2                                    apple rabdi        calcium      veg
# 3                      oats &amp; shallots pulao        protien      veg
# 4                                   peanut gajak  carbohydrates      veg
# 5                 californian breakfast benedict        protien      veg
# 6                               french bean aloo      vitamin_c      veg
# 7                   flax seed and beetroot modak      magnesium      veg
# 8                                   oats khichdi        protien      veg
# 9           stuffed eggplant with schezwan sauce        protien      veg
# 10                                ginger cookies        protien      veg
# 11                   raspberry and balsamic dome      vitamin_a      veg
# 12                                 almond pearls        protien      veg
# 13                         apple and walnut cake      potassium      veg
# 14                             sesame seed pulao  carbohydrates      veg
# 15                    gluten-free christmas cake      vitamin_a      veg
# 16                buldak (hot and spicy chicken)      magnesium  non-veg
# 17                            cashew nut cookies        protien      veg
# 18                           aata walnut cookies      manganese      veg
# 19                       eggless coffee cupcakes      vitamin_d      veg
# 20                 shrimp &amp; cilantro ceviche      vitamin_a      veg
# 21  lemon honey glazed sous vide corn on the cob        protien  non-veg
# 22                           apple and pear cake      potassium      veg
#
#    Price Review                                               Diet  \
# 0    595      5                     high_protien_diet low_fat_diet
# 1    495      5                                  high_protien_diet
# 2    220      3   high_protien_diet vegan_diet ketogenic_diet l...
# 3    330      8                  high_protien_diet high_fiber_diet
# 4    230      9                                  high_protien_diet
# 5    505      2                  high_protien_diet high_fiber_diet
# 6    330      8                                     ketogenic_diet
# 7    335      7                       high_protien_diet vegan_diet
# 8    320      1                  high_protien_diet high_fiber_diet
# 9    565      1                                     ketogenic_diet
# 10   350      8                                      alkaline_diet
# 11   565      3                                    high_fiber_diet
# 12   380      1                                    high_fiber_diet
# 13   655      1                                       low_fat_diet
# 14   555      3                                  high_protien_diet
# 15   360      1                                  high_protien_diet
# 16   695      5                       high_protien_diet vegan_diet
# 17   375      7   high_fiber_diet high_protien_diet vegan_diet ...
# 18   345      2                       high_fiber_diet low_fat_diet
# 19   600      8                                     ketogenic_diet
# 20   480      9                                     ketogenic_diet
# 21   300      2     high_protien_diet high_fiber_diet low_fat_diet
# 22   670      5                       high_fiber_diet low_fat_diet
#
#                                   Disease  \
# 0                               diabeties
# 1                               diabeties
# 2                               diabeties
# 3                 pregnancy heart_disease
# 4                                  goitre
# 5        goitre rickets diabeties obesity
# 6                               diabeties
# 7                  hypertension diabeties
# 8                 pregnancy heart_disease
# 9                                  goitre
# 10                           hypertension
# 11                              diabeties
# 12                                 goitre
# 13                              diabeties
# 14                           hypertension
# 15                  goitre kidney_disease
# 16                                obesity
# 17                                 goitre
# 18                              diabeties
# 19                          goitre anemia
# 20                          goitre anemia
# 21   scurvy hypertension goitre diabeties
# 22                              diabeties
#
#                                           description
# 0   बासमती चावल, अमेरिकन कॉर्न के दाने, जैतून का त...
# 1   walnut brownie, chocolate sauce, chocolate chu...
# 2   apples, milk, sugar, green cardamoms, almonds ...
# 3   चावल, हरा धनिया, हरी मिर्च, प्याज , दालचीनी, इ...
# 4                        jaggery (gur), peanuts, ghee
# 5   brioche loaf, avocado paste, eggs, tomato, spi...
# 6   ns with potatoes cooked with chopped onions, t...
# 7   rice flour, salt, oil (for greasing), beetroot...
# 8   क्विक कुकिंग ओट्स, मूंगदाल, जीरा, हल्दी पाउडर,...
# 9   mixed vegetables, eggplant, cottage cheese, co...
# 10  मक्खन, कैस्टर शुगर, बेकिंग पाउडर, बेकिंग सोडा,...
# 11  dark chocolate, butter, sugar, water, egg, egg...
# 12  toasted almonds, blueberries, oats, corn flake...
# 13  सेब, अंडे, अखरोट, चीनी, अखरोट, तेल, मैदा, बेकि...
# 14  बासमती चावल, लाल मिर्च, तिल, मूंगफली, काजू, ते...
# 15  christmas dry fruits (pre-soaked), orange zest...
# 16  chicken drum sticks/ chicken breast, soy sauce...
# 17  काजू पेस्ट, घी, खांड, फलैक्स या चिया सीडस, बेक...
# 18  butter, castor sugar, aata, baking powder, cof...
# 19  maida/ flour, baking powder, sugar, cocoa powd...
# 20  prawns, gherkin, onion, cilantro, mix bell pep...
# 21  young corn on the cob, honey, lemon juice, gar...
# 22  कोर, छिला और स्लाइस्ड एप्पल, कोर, छिला और स्ला...
